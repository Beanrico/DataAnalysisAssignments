# %% [markdown]
# # Final Project FP-4:  Descriptive Statistics
#
#
# <br>
# <br>

# %% [markdown]
# ___
#
# <br>
#
# # Analysis of Factors Affecting Students’ Academic Performance
#
#
# * **Name**:  Riko Miyabayashi
# * **Student number**:  0300371965
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to determine the factors that contribute to student's academic performance.</span>
# * The dependent variable (DV) is final grade (G3)</span>
# * The independent variables (IVs) include:
# * - school
#   - age
#   - adress
#   - famisize
#   - Pstatus
#   - Medu
#   - Fedu
#   - Mjob
#   - Fjob
#   - reason
#   - gurdian
#   - traveltime
#   - studytime
#   - failures
#   - schoolsup
#   - famsup
#   - paid
#   - activities
#   - nursery
#   - higher
#   - internet
#   - romantic
#   - famrel
#   - freetime
#   - goout
#   - Dalc
#   - Walc
#   - health
#   - abcences
#   - G1
#   - G2</span>
# * The dataset contains information on 649 students from two Portuguese secondary schools. There are no missing values.</span>
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# The data come from the student performance dataset from the UCI Machine Learning repository:</span>
#
# The data are available for download [here](https://archive.ics.uci.edu/ml/datasets/Student+Performance)</span>
#
# Analyses of this dataset have been published previously in Cortez et al. (2008).</span>
#
# #### Reference:
# P. Cortez, A. M. G. Silva (2008). Using data mining to predict secondary school student
# In: Proceedings of 5th Annual Future Business Technology Conference
# doi: [10.24432/C5TG7T](https://doi.org/10.24432/C5TG7T)</span>
#
# <br>

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
import parse_data as pd
import descriptive as de

# %%
df = pd.df
df.describe()

# %%
de.display_title('Central tendency summary statistics.', pref='Table',num = 1, center=False)
de.central_table(df)

# %%
de.display_title('Correlations amongst main variables.', pref='Figure', num=1)
de.plot_descriptive(pd.G1, pd.st, pd.ab, pd.G3)
