# %% [markdown]
# # FP-1:  Final Project Proposal
#
#
# Instructions:
# - Find a dataset as described in class
# - Fill in all <span style="color:blue">blue text fields</span> below;  also follow the Example Proposal below
# - Delete this Markdown cell and all Example Proposal Markdown cells

# %% [markdown]
# ___
#
# # <span style="color:blue">Analysis of Factors Affecting Students’ Academic Performance</span>
#
#
# ### Overview:
#
# * **Name**:  <span style="color:blue">Riko Miyabayashi</span>
# * **Student number**:  <span style="color:blue">0300371965</span>
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * <span style="color:blue">The purpose of this Final Project is to determine the factors that contribute to student's academic performance.</span>
# * <span style="color:blue">The dependent variable (DV) is final grade (G3)</span>
# * <span style="color:blue">The independent variables (IVs) include:
# * - school
#   - age
#   - adress
#   - famisize
#   - Pstatus
#   - Medu
#   - Fedu
#   - Mjob
#   - Fjob
#   - reason
#   - gurdian
#   - traveltime
#   - studytime
#   - failures
#   - schoolsup
#   - famsup
#   - paid
#   - activities
#   - nursery
#   - higher
#   - internet
#   - romantic
#   - famrel
#   - freetime
#   - goout
#   - Dalc
#   - Walc
#   - health
#   - abcences
#   - G1
#   - G2</span>
# * <span style="color:blue">The dataset contains information on 649 students from two Portuguese secondary schools. There are no missing values.</span>
# <span style="color:blue"></span>
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# <span style="color:blue">The data come from the student performance dataset from the UCI Machine Learning repository:</span>
#
# <span style="color:blue">The data are available for download [here](https://archive.ics.uci.edu/ml/datasets/Student+Performance)</span>
#
# <span style="color:blue">Analyses of this dataset have been published previously in Cortez et al. (2008).</span>
#
# #### <span style="color:blue">Reference:
# P. Cortez, A. M. G. Silva (2008). Using data mining to predict secondary school student
# In: Proceedings of 5th Annual Future Business Technology Conference
# doi: [10.24432/C5TG7T](https://doi.org/10.24432/C56S3T)performance</span>
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ___
#
# ### <span style="color:red">Example proposal:</span>
#
# <br>
#
# # Analysis of factors contributing to red wine quality
#
#
# * **Name**:  Taro KYODAI
# * **Student number**:  123456789
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to determine the factors that contribute to red wine quality.
# * The key **dependent variable** (DV) is wine quality, an integer between 0 and 10, as judged by experts.
# * Key **independent variables** (IVs) include:
#     * fixed acidity
#     * volatile acidity
#     * citric acid
#     * residual sugar
#     * chlorides
#     * free sulfur dioxide
#     * total sulfur dioxide
#     * density
#     * pH
#     * sulphates
#     * alcohol
# * This dataset contains 1599 cases (i.e., 1599 different red wines). Each wine has values for all IVs as well as the DV.
# <br>

# %% [markdown]
# ### Dataset source:
#
# The data come from the [wine quality](https://archive.ics.uci.edu/ml/datasets/Wine+Quality) dataset from the [UCI Machine Learning repository](https://archive.ics.uci.edu/ml/index.php):
#
# The data are available for download [here](https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/).
#
# Analyses of this dataset have been published previously in Cortez et al. (2009).
#
#
# #### References:
#
# P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis (2009). Modeling wine preferences by data mining from physicochemical properties. In: Decision Support Systems, Elsevier, 47(4):547-553.
# doi: [10.1016/j.dss.2009.05.016](https://doi.org/10.1016/j.dss.2009.05.016)
