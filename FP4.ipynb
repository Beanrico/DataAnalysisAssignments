# %%
# %run myscript.py

# %%
print(x,y)
# Out:
# 1 11

# %%
import mymodule as mm

print(mm)
# Out:
# <module 'mymodule' from '/Users/miyabayashiriko/Documents/GitHub/DataAnalysisAssignments/mymodule.py'>

# %%
a=mm.myfunction(5)

print(a)
# Out:
# 15
