# %%
import pandas as pd
from analysis.tables import central_table, dispersion_table
from analysis.plotting import plot_descriptive
from analysis.util import display_title
# %run parse_data.ipynb

# 目的変数と説明変数
G1 = df['G1'].values
G3 = df['G3'].values
st = df['studytime'].values
ab = df['absences'].values

# %%
display_title("Central Tendency")
central_table(df[['G1','G3','studytime','absences']])
# Out:
# Central Tendency
#                G1        G3  studytime  absences
# Mean    10.908861  10.41519   2.035443  5.708861
# Median  11.000000  11.00000   2.000000  4.000000
# Mode    10.000000  10.00000   2.000000  0.000000

# %%
display_title("Dispersion Statistics")
dispersion_table(df[['G1','G3','studytime','absences']])
# Out:
# Dispersion Statistics
#              G1        G3  studytime   absences
# Std     3.31499   4.57564   0.838177   7.992959
# Min     3.00000   0.00000   1.000000   0.000000
# Max    19.00000  20.00000   4.000000  75.000000
# Range  16.00000  20.00000   3.000000  75.000000
# 25%     8.00000   8.00000   1.000000   0.000000
# 75%    13.00000  14.00000   2.000000   8.000000
# IQR     5.00000   6.00000   1.000000   8.000000

# %%
display_title("Descriptive Plots", num=1)
plot_descriptive(G1, st, ab, G3)
# Out:
# Descriptive Plots (Figure 1)
